# %%
from facenet_pytorch import MTCNN, InceptionResnetV1, fixed_image_standardization, training
import torch
from torch._C import Size
from torch.nn.modules.module import T
from torch.utils.data import DataLoader, SubsetRandomSampler
from torch import optim
from torch.optim.lr_scheduler import MultiStepLR
from torch.utils.tensorboard import SummaryWriter
from torchvision import datasets, transforms
import numpy as np
import os
import copy


SEED = 1234

import random
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

data_dir = 'TestSet_cropped'

batch_size = 512
epochs = 8
workers = 0 if os.name == 'nt' else 8 

device = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')
print('Running on device: {}'.format(device))

dataset = datasets.ImageFolder(data_dir)


loader = DataLoader(
    dataset,
    num_workers=workers,
    batch_size=batch_size,
    collate_fn=training.collate_pil
)

trans = transforms.Compose([
    np.float32,
    transforms.ToTensor(),
    fixed_image_standardization # [0,255] -> [-1,1]
])

dataset = datasets.ImageFolder(data_dir, transform=trans)
img_inds = np.arange(len(dataset))

test_loader = DataLoader( 
    dataset,
    num_workers=workers,
    batch_size=1,
)
resnet = InceptionResnetV1(
    classify=True,
#    pretrained='vggface2',
    pretrained='casia-webface', #'vggface2'
    num_classes=len(dataset.class_to_idx)
).to(device)

resnet.load_state_dict(torch.load('./Rushi_GeorgiaTech-TestDataset_StateDict.pth'))

loss_fn = torch.nn.CrossEntropyLoss()
metrics = { 
    'fps': training.BatchTimer(),
    'acc': training.accuracy
}

import cv2
import mediapipe as mp
import numpy as np
from math import hypot
from imutils import paths
import os


# Face Mesh
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh() 

mtcnn = MTCNN(
    image_size=160, margin=0, min_face_size=20,
    thresholds=[0.6, 0.7, 0.7], factor=0.709, post_process=True,
    device=device
)

def collate_fn(x):
    return x[0]

dataset = datasets.ImageFolder(data_dir)
dataset.idx_to_class = {i:c for c, i in dataset.class_to_idx.items()}
loader = DataLoader(dataset, collate_fn=collate_fn, num_workers=workers)

def get_landmarks(location, frame_patch_width, frame_patch_height, global_patch_width, facial_landmarks):

 # Nose Co-ordinates
    if location == 'Nose':
        top = (facial_landmarks.landmark[8].x * frame_patch_width, facial_landmarks.landmark[8].y * frame_patch_height)
        center = (facial_landmarks.landmark[195].x * frame_patch_width, facial_landmarks.landmark[195].y * frame_patch_height)

        left_point = (facial_landmarks.landmark[190].x * frame_patch_width, facial_landmarks.landmark[190].y * frame_patch_height)
        right_point = (facial_landmarks.landmark[413].x * frame_patch_width, facial_landmarks.landmark[413].y * frame_patch_height)

        # patch_width = int(hypot(left_point[0] - right_point[0],
        #                     left_point[1] - right_point[1]))

        patch_width = global_patch_width
        patch_height = int(patch_width)                      

        top_left = (int(center[0] - patch_width / 2),
                        int(center[1] - patch_height /2))

        bottom_right = (int(center[0] + patch_width / 2),
                            int(center[1] + patch_height / 2))


    # Chin Coordinates
    if location == 'Chin':
        center = (facial_landmarks.landmark[199].x * frame_patch_width, facial_landmarks.landmark[199].y * frame_patch_height)

        left_point = (facial_landmarks.landmark[140].x * frame_patch_width, facial_landmarks.landmark[140].y * frame_patch_height)
        right_point = (facial_landmarks.landmark[428].x * frame_patch_width, facial_landmarks.landmark[428].y * frame_patch_height)

        # patch_width = int(hypot(left_point[0] - right_point[0],
        #                     left_point[1] - right_point[1]))

        patch_width = global_patch_width
        patch_height = int(patch_width)                      

        top_left = (int(center[0] - patch_width / 2),
                        int(center[1] - patch_height /2))

        bottom_right = (int(center[0] + patch_width / 2),
                            int(center[1] + patch_height / 2))

    # Cheek Coordinates
    if location == 'Cheek':
        center = (facial_landmarks.landmark[205].x * frame_patch_width, facial_landmarks.landmark[205].y * frame_patch_height)

        # patch_width = int(hypot(left_point[0] - right_point[0],
        #                     left_point[1] - right_point[1]))

        patch_width = global_patch_width
        patch_height = int(patch_width)                      

        top_left = (int(center[0] - patch_width / 2),
                        int(center[1] - patch_height /2))


    if location == 'Forehead':
        center = (facial_landmarks.landmark[151].x * frame_patch_width, facial_landmarks.landmark[151].y * frame_patch_height)

        # patch_width = int(hypot(left_point[0] - right_point[0],
        #                     left_point[1] - right_point[1]))

        patch_width = global_patch_width
        patch_height = int(patch_width)                      

        top_left = (int(center[0] - patch_width / 2),
                        int(center[1] - patch_height /2))



            
    return patch_width, patch_height, top_left


def get_multi_landmarks(location, frame_width, frame_height, target_patch_size_w, target_patch_size_h, facial_landmarks):

    if location == 'N-F-C':  # NOSE-Forehead-Cheek
        ## NOSE

        nose_center = (facial_landmarks.landmark[195].x * frame_width, facial_landmarks.landmark[195].y * frame_height)

        nose_patch_width = target_patch_size_w
        nose_patch_height = target_patch_size_h                      

        nose_top_left = (int(nose_center[0] - nose_patch_width / 2),
                        int(nose_center[1] - nose_patch_height /2))            

        ## Forehead 
        forehead_center = (facial_landmarks.landmark[151].x * frame_width, facial_landmarks.landmark[151].y * frame_height)

        forehead_patch_width = target_patch_size_w
        forehead_patch_height = target_patch_size_h                      

        forehead_top_left = (int(forehead_center[0] - forehead_patch_width / 2),
                        int(forehead_center[1] - forehead_patch_height /2))

        ## CHEEK 
        cheek_center = (facial_landmarks.landmark[205].x * frame_width, facial_landmarks.landmark[205].y * frame_height)

        cheek_patch_width = target_patch_size_w
        cheek_patch_height = target_patch_size_h                      

        cheek_top_left = (int(cheek_center[0] - cheek_patch_width / 2),
                        int(cheek_center[1] - cheek_patch_height /2))

    return nose_patch_width, nose_patch_height, nose_top_left, forehead_patch_width, forehead_patch_height, forehead_top_left, cheek_patch_width, cheek_patch_height, cheek_top_left


def fgsm_attack(image, epsilon, data_grad):
    # Collect the element-wise sign of the data gradient
    sign_data_grad = data_grad.sign()
    # Create the perturbed image by adjusting each pixel of the input image
    perturbed_image = image + epsilon*sign_data_grad
    # Adding clipping to maintain [-1,1] range
    perturbed_image = torch.clamp(perturbed_image, -1, 1)
    # Return the perturbed image   
    noise_matrix = epsilon*sign_data_grad
    #torch.save(noise_matrix, "NoiseMatrix_{0}.pth".format(eps_value))

    return perturbed_image, noise_matrix

loop_005 = []
loop_01 = []
loop_02 = []
loop_04 = []
loop_08 = []
loop_1 = []

def pass_epoch(
    model, eps, patch, LOCATION, SIZE, loss_fn, loader,
    device='cuda'
):
    
    mode = 'Train' if model.training else 'Valid'
    loss = 0
    metrics = {}
    
    epsilon_value = eps
    location = LOCATION
    global_patch_width = SIZE
    target_patch_size_w, target_patch_size_h = SIZE, SIZE

    correct = 0
    num_fooled = 0
    num_initial_error = 0
    
    adv_examples = []
    
    bd_image = cv2.imread("BD.jpg")
    bd_image = cv2.cvtColor(bd_image, cv2.COLOR_BGR2RGB)

    from torchvision import transforms
    trans = transforms.Compose([transforms.ToTensor()])
    
    for i_batch, (X, y) in enumerate(loader):
        X = X.to(device)
        y = y.to(device)
        
        loop_count = 0
        
        X.requires_grad = True
        
        y_pred = model(X)
        loss_batch = loss_fn(y_pred, y)

        init_pred = y_pred.max(1, keepdim=True)[1] # get the index of the max log-probability
        

        #If the initial prediction is wrong, dont bother attacking, just move on
        if init_pred.item() != y.item():
            num_initial_error += 1
            print("INSIDE")
            print(init_pred, y)
            continue
            
        model.zero_grad()
        loss_batch.backward()
        
        data_grad = X.grad.data 

        perturbed_data, noise_matrix_orig = fgsm_attack(X, epsilon_value, data_grad)
        
        ####### FRAME OPERATIONS NOW ###########
        
        frame = X[0].detach().cpu().numpy()
        frame = np.transpose(frame, (1,2,0))
        frame = (frame*128)+127.5
        frame = frame.astype(np.uint8)
    

        Orig_image = copy.deepcopy(frame)
        Orig_image = cv2.cvtColor(Orig_image, cv2.COLOR_RGB2BGR)

        frame_height, frame_width, _ = frame.shape

        result = face_mesh.process(frame)    
        
        np_img = perturbed_data[0].detach().cpu().numpy()
        np_img = np.transpose(np_img, (1,2,0))
        np_img = (np_img*128)+127.5
        np_img = np_img.astype(np.uint8)
    
    
        for facial_landmarks in result.multi_face_landmarks:
            
            if location in ['N-F-C', 'N-F']:
                nose_patch_width, nose_patch_height, nose_top_left, forehead_patch_width, forehead_patch_height, forehead_top_left, cheek_patch_width, cheek_patch_height, cheek_top_left = get_multi_landmarks(location, frame_width, frame_height, 
                                                                                     target_patch_size_w, target_patch_size_h, facial_landmarks)

                #### NOSE AREA ####
                
                nose_area = np_img[nose_top_left[1]: nose_top_left[1] + nose_patch_height, 
                                   nose_top_left[0]: nose_top_left[0] + nose_patch_width]
                
                frame[nose_top_left[1]: nose_top_left[1] + nose_patch_height,
                    nose_top_left[0]: nose_top_left[0] + nose_patch_width] = copy.deepcopy(nose_area)
                
                #### FOREHEAD AREA ####
                
                forehead_area = np_img[forehead_top_left[1]: forehead_top_left[1] + forehead_patch_height, 
                                   forehead_top_left[0]: forehead_top_left[0] + forehead_patch_width]
                
                frame[forehead_top_left[1]: forehead_top_left[1] + forehead_patch_height,
                    forehead_top_left[0]: forehead_top_left[0] + forehead_patch_width] = copy.deepcopy(forehead_area)
                
                #### CHEEK AREA ####
                
                cheek_area = np_img[cheek_top_left[1]: cheek_top_left[1] + cheek_patch_height, 
                                    cheek_top_left[0]: cheek_top_left[0] + cheek_patch_width]
                
                frame[cheek_top_left[1]: cheek_top_left[1] + cheek_patch_height,
                    cheek_top_left[0]: cheek_top_left[0] + cheek_patch_width] = copy.deepcopy(cheek_area)
                
            else:
                patch_width, patch_height, top_left = get_landmarks(location, frame_width, frame_height, global_patch_width, facial_landmarks)

                reqd_matrix = np_img[top_left[1]: top_left[1] + patch_height, top_left[0]: top_left[0] + patch_width]
                
                frame[top_left[1]: top_left[1] + patch_height, top_left[0]: top_left[0] + patch_width] = copy.deepcopy(reqd_matrix)

        #frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        aligned = []
        x_aligned, prob = mtcnn(frame, return_prob=True)
        aligned.append(x_aligned)
        
        try:
            faces = torch.stack(aligned).to(device)
        except:
            print("Issue in tensor - ", faces.shape)
                        
        output = model(faces)
        
        # Check for success
        final_pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
        
        if final_pred.item() != y.item():
            print("Fooled in the first iteration itself, IMAGE - ", i_batch)
            #frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
            #cv2.imwrite(f'./Pic_Base/{location}_{SIZE}/{epsilon_value:.2f}_{i_batch:02}_Fooled_first.jpg', frame)
            #Noise_image = np.abs(frame-Orig_image)
            #cv2.imwrite(f'./Pic_Base/{location}_{SIZE}/{epsilon_value:.2f}_{i_batch:02}_Noise_first.jpg', Noise_image)
            
            if epsilon_value == 0.05:
                loop_005.append(1)

            if epsilon_value == 0.1:
                loop_01.append(1)

            if epsilon_value == 0.2:
                loop_02.append(1)

            if epsilon_value == 0.4:
                loop_04.append(1)
                
            if epsilon_value == 0.8:
                loop_08.append(1)

            if epsilon_value == 1:
                loop_1.append(1)
            
        if final_pred.item() == y.item():
            #print("Image No - ", i_batch)
            
            for i in range(200):

                #update data_grad-----------------------
#                 face_clone = faces.clone()
#                 face_clone.requires_grad = True
        
                faces.requires_grad = True
                y_pred = model(faces) #face_clone
                loss_batch = loss_fn(y_pred, y)

                model.zero_grad()
                loss_batch.backward(retain_graph=True)
        
                data_grad = faces.grad.data  #face_clone
                #---------------------------------------
                perturbed_data, noise_matrix = fgsm_attack(faces, epsilon_value, data_grad)
                    
                np_img = perturbed_data[0].detach().cpu().numpy()
                np_img = np.transpose(np_img, (1,2,0))
                np_img = (np_img*128)+127.5
                np_img = np_img.astype(np.uint8)

                if location in ['N-F-C', 'N-F']:
                    nose_patch_width, nose_patch_height, nose_top_left, forehead_patch_width, forehead_patch_height, forehead_top_left, cheek_patch_width, cheek_patch_height, cheek_top_left = get_multi_landmarks(location, frame_width, frame_height, 
                                                                                         target_patch_size_w, target_patch_size_h, facial_landmarks)

                    #### NOSE AREA ####

                    nose_area = np_img[nose_top_left[1]: nose_top_left[1] + nose_patch_height, 
                                       nose_top_left[0]: nose_top_left[0] + nose_patch_width]

                    frame[nose_top_left[1]: nose_top_left[1] + nose_patch_height,
                        nose_top_left[0]: nose_top_left[0] + nose_patch_width] = copy.deepcopy(nose_area)

                    #### FOREHEAD AREA ####

                    forehead_area = np_img[forehead_top_left[1]: forehead_top_left[1] + forehead_patch_height, 
                                       forehead_top_left[0]: forehead_top_left[0] + forehead_patch_width]

                    frame[forehead_top_left[1]: forehead_top_left[1] + forehead_patch_height,
                        forehead_top_left[0]: forehead_top_left[0] + forehead_patch_width] = copy.deepcopy(forehead_area)

                    #### CHEEK AREA ####

                    cheek_area = np_img[cheek_top_left[1]: cheek_top_left[1] + cheek_patch_height, 
                                        cheek_top_left[0]: cheek_top_left[0] + cheek_patch_width]

                    frame[cheek_top_left[1]: cheek_top_left[1] + cheek_patch_height,
                        cheek_top_left[0]: cheek_top_left[0] + cheek_patch_width] = copy.deepcopy(cheek_area)
                
                else:
                    patch_width, patch_height, top_left = get_landmarks(location, frame_width, frame_height, global_patch_width, facial_landmarks)

                    reqd_matrix = np_img[top_left[1]: top_left[1] + patch_height, top_left[0]: top_left[0] + patch_width]

                aligned = []
                x_aligned, prob = mtcnn(frame, return_prob=True)
                aligned.append(x_aligned)
                
                try:
                    faces = torch.stack(aligned).to(device)
                except:
                    print("Issue in tensor - ", faces.shape)

                output = model(faces)

                 # Check for success
                final_pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
                
                if i > 198:
                    print("Breaking out of loop for Image - {0} didn't fool".format(i_batch))
                    #frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
                    #cv2.imwrite(f'./Pic_Base/{location}_{SIZE}/{epsilon_value:.2f}_{i_batch:02}_Failed.jpg', frame)
                    break
                
                if final_pred.item() != y.item():
                    print("For epsilon - {0} and Image - {1} it took {2} loops".format(epsilon_value, i_batch, i+2))
                    
                    if epsilon_value == 0.05:
                        loop_005.append(i+2)

                    if epsilon_value == 0.1:
                        loop_01.append(i+2)

                    if epsilon_value == 0.2:
                        loop_02.append(i+2)

                    if epsilon_value == 0.4:
                        loop_04.append(i+2)
                        
                    if epsilon_value == 0.8:
                        loop_08.append(1)

                    if epsilon_value == 1:
                        loop_1.append(i+2)
                    
                    #frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
                    #cv2.imwrite(f'./Pic_Base/{location}_{SIZE}/{epsilon_value:.2f}_{i_batch:02}_Fooled.jpg', frame)
                    #Noise_image = np.abs(frame-Orig_image)
                    #cv2.imwrite(f'./Pic_Base/{location}_{SIZE}/{epsilon_value:.2f}_{i_batch:02}_Noise.jpg', Noise_image)
                    break
                    
            #print(epsilon_value, final_pred.item(), y.item())
             
            
        else:
            correct += 1
                
        final_pred = output.max(1, keepdim=True)[1]
        if final_pred.item() != y.item():
            #print("FOOLED !!! ", final_pred.item(), y.item())
            num_fooled += 1
                
                
    fool_rate = num_fooled/(float(len(loader)-num_initial_error))
    print("Epsilon: {}\tFool Rate = {} / {} = {}".format(epsilon_value, num_fooled, len(loader)-num_initial_error, fool_rate))
    
    return num_fooled, epsilon_value, loop_005, loop_01, loop_02, loop_04, loop_08, loop_1, fool_rate
# Out:
# Running on device: cuda:3

# %%
import time

fool_rates = []
examples = []

#====パラメータ指定=====

#epsilons = [0.1]
epsilons = [0.1, 0.2, 0.4, 0.8, 1]
#epsilons = [0.05, 0.1, 0.2, 0.4, 1]
#LOCATIONS = ['Nose','Forehead','Cheek', 'Chin']
LOCATION = 'N-F-C'
#TARGET_PATCH_SIZES = [30]
TARGET_PATCH_SIZES = [30] # 15, 20, 35, 40

#=====================

resnet.eval()

print('Calcuate non_adversarial accuracy')
moderu = resnet
missNumber = 0
photoNumber = 0

# for j_batch, (A, b) in enumerate(test_loader):
#         A = A.to(device)
#         b = b.to(device)
#         A.requires_grad = True
#         b_pred = moderu(A)
#         loss_batch = loss_fn(b_pred, b)

#         first_pred = b_pred.max(1, keepdim=True)[1] # get the index of the max log-probability
        
#         #If the initial prediction is wrong, dont bother attacking, just move on
#         #print('pred: {}  : label: {}'.format(first_pred.item(),b.item()))
#         photoNumber =  photoNumber+1
#         if first_pred.item() != b.item():
#             print("Can'tPredict")
#             print(first_pred, b)
#             missNumber = missNumber+1
#             continue
             
# seitouritu = (missNumber/photoNumber)*100
# print('{}: {} : {}'.format(missNumber, photoNumber, seitouritu))

print('LOCATION TEST')

result = {}
eps_dict = {0.05 : "loop_005", 0.1 : "loop_01", 0.2 : "loop_02", 0.4 : "loop_04", 1 : "loop_1"}
             
for TARGET_PATCH_SIZE in TARGET_PATCH_SIZES:

    patch = False

    if not os.path.exists(f'./Pic_Base250/{LOCATION}_{TARGET_PATCH_SIZE}') :
        os.mkdir(f'./Pic_Base250/{LOCATION}_{TARGET_PATCH_SIZE}')
    if not os.path.exists(f'./Array_Base250/{LOCATION}_{TARGET_PATCH_SIZE}') :
        os.mkdir(f'./Array_Base250/{LOCATION}_{TARGET_PATCH_SIZE}')

    start = time.time()
    print(LOCATION)
    fool_nums = []
    shift_fool_rates = np.zeros((4,2))

    for eps in epsilons:
        num_fooled, eps_value, loop_005, loop_01, loop_02, loop_04, loop_08, loop_1, fool_rate = pass_epoch(
            resnet, eps, patch, LOCATION, TARGET_PATCH_SIZE, loss_fn, test_loader, device=device
        )

#             fool_nums.append(num_fooled)

#             fool_rate = [(len(fool_nums)/250) * 100]

#         if eps in eps_dict:
#             if fool_rate!=0:
#                 a_file = open(f'Array_Base250/Eps_{eps}/{LOCATION}_{TARGET_PATCH_SIZE}/{eps_dict[eps]}.txt', "w")

#                 np.savetxt(a_file, fool_rate, delimiter=',', fmt="%s")
#                 a_file.close()

        #result[LOCATION] = {eps, fool_rate}

    end = time.time() - start

    print("Time taken for this run - ", end)

    print(len(loop_005)) 
    print(len(loop_01))
    print(len(loop_02))
    print(len(loop_04))
    print(len(loop_08))
    print(len(loop_1))

    np.savetxt(f'Array_Base250/{LOCATION}_{TARGET_PATCH_SIZE}/Loop_0.05.csv', loop_005, delimiter=',')
    np.savetxt(f'Array_Base250/{LOCATION}_{TARGET_PATCH_SIZE}/Loop_0.10.csv', loop_01, delimiter=',')
    np.savetxt(f'Array_Base250/{LOCATION}_{TARGET_PATCH_SIZE}/Loop_0.20.csv', loop_02, delimiter=',')
    np.savetxt(f'Array_Base250/{LOCATION}_{TARGET_PATCH_SIZE}/Loop_0.40.csv', loop_04, delimiter=',')
    np.savetxt(f'Array_Base250/{LOCATION}_{TARGET_PATCH_SIZE}/Loop_0.80.csv', loop_08, delimiter=',')
    np.savetxt(f'Array_Base250/{LOCATION}_{TARGET_PATCH_SIZE}/Loop_1.00.csv', loop_1, delimiter=',')

    np.savetxt(f'Array_Base250/{LOCATION}_{TARGET_PATCH_SIZE}/fool_nums.csv', fool_nums, delimiter=',')
    loop_005 = []
    loop_01 = []
    loop_02 = []
    loop_04 = []
    loop_08 = []
    loop_1 = []
# Out:
# Calcuate non_adversarial accuracy
# LOCATION TEST
# N-F-C
# For epsilon - 0.1 and Image - 0 it took 3 loops
# For epsilon - 0.1 and Image - 1 it took 8 loops
# For epsilon - 0.1 and Image - 2 it took 10 loops
# For epsilon - 0.1 and Image - 3 it took 5 loops
# For epsilon - 0.1 and Image - 4 it took 8 loops
# For epsilon - 0.1 and Image - 5 it took 4 loops
# For epsilon - 0.1 and Image - 6 it took 3 loops
# For epsilon - 0.1 and Image - 7 it took 2 loops
# For epsilon - 0.1 and Image - 8 it took 3 loops
# For epsilon - 0.1 and Image - 9 it took 6 loops
# For epsilon - 0.1 and Image - 10 it took 2 loops
# For epsilon - 0.1 and Image - 11 it took 2 loops
# For epsilon - 0.1 and Image - 12 it took 4 loops
# For epsilon - 0.1 and Image - 13 it took 2 loops
# For epsilon - 0.1 and Image - 14 it took 2 loops
# For epsilon - 0.1 and Image - 15 it took 7 loops
# For epsilon - 0.1 and Image - 16 it took 9 loops
# For epsilon - 0.1 and Image - 17 it took 7 loops
# For epsilon - 0.1 and Image - 18 it took 3 loops
# For epsilon - 0.1 and Image - 19 it took 6 loops
# For epsilon - 0.1 and Image - 20 it took 4 loops
# For epsilon - 0.1 and Image - 21 it took 192 loops
# For epsilon - 0.1 and Image - 22 it took 5 loops
# For epsilon - 0.1 and Image - 23 it took 9 loops
# For epsilon - 0.1 and Image - 24 it took 2 loops
# For epsilon - 0.1 and Image - 25 it took 12 loops
# For epsilon - 0.1 and Image - 26 it took 2 loops
# For epsilon - 0.1 and Image - 27 it took 3 loops
# For epsilon - 0.1 and Image - 28 it took 6 loops
# For epsilon - 0.1 and Image - 29 it took 2 loops
# For epsilon - 0.1 and Image - 30 it took 2 loops
# For epsilon - 0.1 and Image - 31 it took 2 loops
# For epsilon - 0.1 and Image - 32 it took 2 loops
# For epsilon - 0.1 and Image - 33 it took 2 loops
# For epsilon - 0.1 and Image - 34 it took 2 loops
# For epsilon - 0.1 and Image - 35 it took 2 loops
# For epsilon - 0.1 and Image - 36 it took 2 loops
# For epsilon - 0.1 and Image - 37 it took 2 loops
# For epsilon - 0.1 and Image - 38 it took 2 loops
# For epsilon - 0.1 and Image - 39 it took 3 loops
# For epsilon - 0.1 and Image - 40 it took 3 loops
# For epsilon - 0.1 and Image - 41 it took 3 loops
# For epsilon - 0.1 and Image - 42 it took 4 loops
# For epsilon - 0.1 and Image - 43 it took 4 loops
# For epsilon - 0.1 and Image - 44 it took 4 loops
# For epsilon - 0.1 and Image - 45 it took 6 loops
# For epsilon - 0.1 and Image - 46 it took 5 loops
# For epsilon - 0.1 and Image - 47 it took 126 loops
# For epsilon - 0.1 and Image - 48 it took 5 loops
# For epsilon - 0.1 and Image - 49 it took 7 loops
# For epsilon - 0.1 and Image - 50 it took 12 loops
# For epsilon - 0.1 and Image - 51 it took 39 loops
# For epsilon - 0.1 and Image - 52 it took 7 loops
# For epsilon - 0.1 and Image - 53 it took 13 loops
# For epsilon - 0.1 and Image - 54 it took 11 loops
# For epsilon - 0.1 and Image - 55 it took 14 loops
# Breaking out of loop for Image - 56 didn't fool
# For epsilon - 0.1 and Image - 57 it took 10 loops
# For epsilon - 0.1 and Image - 58 it took 10 loops
# For epsilon - 0.1 and Image - 59 it took 76 loops
# For epsilon - 0.1 and Image - 60 it took 2 loops
# For epsilon - 0.1 and Image - 61 it took 2 loops
# For epsilon - 0.1 and Image - 62 it took 2 loops
# For epsilon - 0.1 and Image - 63 it took 2 loops
# For epsilon - 0.1 and Image - 64 it took 3 loops
# For epsilon - 0.1 and Image - 65 it took 6 loops
# For epsilon - 0.1 and Image - 66 it took 5 loops
# For epsilon - 0.1 and Image - 67 it took 5 loops
# For epsilon - 0.1 and Image - 68 it took 5 loops
# For epsilon - 0.1 and Image - 69 it took 4 loops
# For epsilon - 0.1 and Image - 70 it took 3 loops
# For epsilon - 0.1 and Image - 71 it took 3 loops
# For epsilon - 0.1 and Image - 72 it took 3 loops
# For epsilon - 0.1 and Image - 73 it took 3 loops
# For epsilon - 0.1 and Image - 74 it took 3 loops
# For epsilon - 0.1 and Image - 75 it took 25 loops
# For epsilon - 0.1 and Image - 76 it took 3 loops
# For epsilon - 0.1 and Image - 77 it took 6 loops
# For epsilon - 0.1 and Image - 78 it took 10 loops
# For epsilon - 0.1 and Image - 79 it took 11 loops
# For epsilon - 0.1 and Image - 80 it took 2 loops
# For epsilon - 0.1 and Image - 81 it took 2 loops
# For epsilon - 0.1 and Image - 82 it took 2 loops
# For epsilon - 0.1 and Image - 83 it took 3 loops
# For epsilon - 0.1 and Image - 84 it took 4 loops
# For epsilon - 0.1 and Image - 85 it took 3 loops
# For epsilon - 0.1 and Image - 86 it took 2 loops
# For epsilon - 0.1 and Image - 87 it took 2 loops
# For epsilon - 0.1 and Image - 88 it took 2 loops
# Fooled in the first iteration itself, IMAGE -  89
# For epsilon - 0.1 and Image - 90 it took 136 loops
# For epsilon - 0.1 and Image - 91 it took 8 loops
# For epsilon - 0.1 and Image - 92 it took 4 loops
# For epsilon - 0.1 and Image - 93 it took 4 loops
# For epsilon - 0.1 and Image - 94 it took 155 loops
# For epsilon - 0.1 and Image - 95 it took 7 loops
# For epsilon - 0.1 and Image - 96 it took 4 loops
# For epsilon - 0.1 and Image - 97 it took 5 loops
# For epsilon - 0.1 and Image - 98 it took 102 loops
# For epsilon - 0.1 and Image - 99 it took 3 loops
# For epsilon - 0.1 and Image - 100 it took 6 loops
# For epsilon - 0.1 and Image - 101 it took 6 loops
# For epsilon - 0.1 and Image - 102 it took 6 loops
# For epsilon - 0.1 and Image - 103 it took 5 loops
# For epsilon - 0.1 and Image - 104 it took 5 loops
# For epsilon - 0.1 and Image - 105 it took 5 loops
# For epsilon - 0.1 and Image - 106 it took 11 loops
# For epsilon - 0.1 and Image - 107 it took 3 loops
# For epsilon - 0.1 and Image - 108 it took 9 loops
# For epsilon - 0.1 and Image - 109 it took 11 loops
# For epsilon - 0.1 and Image - 110 it took 3 loops
# For epsilon - 0.1 and Image - 111 it took 3 loops
# For epsilon - 0.1 and Image - 112 it took 2 loops
# For epsilon - 0.1 and Image - 113 it took 9 loops
# For epsilon - 0.1 and Image - 114 it took 4 loops
# For epsilon - 0.1 and Image - 115 it took 5 loops
# For epsilon - 0.1 and Image - 116 it took 6 loops
# For epsilon - 0.1 and Image - 117 it took 8 loops
# For epsilon - 0.1 and Image - 118 it took 20 loops
# For epsilon - 0.1 and Image - 119 it took 4 loops
# For epsilon - 0.1 and Image - 120 it took 3 loops
# For epsilon - 0.1 and Image - 121 it took 18 loops
# For epsilon - 0.1 and Image - 122 it took 6 loops
# For epsilon - 0.1 and Image - 123 it took 24 loops
# For epsilon - 0.1 and Image - 124 it took 8 loops
# For epsilon - 0.1 and Image - 125 it took 4 loops
# For epsilon - 0.1 and Image - 126 it took 2 loops
# For epsilon - 0.1 and Image - 127 it took 2 loops
# For epsilon - 0.1 and Image - 128 it took 2 loops
# For epsilon - 0.1 and Image - 129 it took 2 loops
# Fooled in the first iteration itself, IMAGE -  130
# Fooled in the first iteration itself, IMAGE -  131
# For epsilon - 0.1 and Image - 132 it took 2 loops
# Fooled in the first iteration itself, IMAGE -  133
# For epsilon - 0.1 and Image - 134 it took 2 loops
# For epsilon - 0.1 and Image - 135 it took 4 loops
# For epsilon - 0.1 and Image - 136 it took 8 loops
# For epsilon - 0.1 and Image - 137 it took 5 loops
# For epsilon - 0.1 and Image - 138 it took 2 loops
# For epsilon - 0.1 and Image - 139 it took 4 loops
# For epsilon - 0.1 and Image - 140 it took 2 loops
# Fooled in the first iteration itself, IMAGE -  141
# For epsilon - 0.1 and Image - 142 it took 2 loops
# For epsilon - 0.1 and Image - 143 it took 2 loops
# For epsilon - 0.1 and Image - 144 it took 2 loops
# For epsilon - 0.1 and Image - 145 it took 4 loops
# For epsilon - 0.1 and Image - 146 it took 3 loops
# For epsilon - 0.1 and Image - 147 it took 11 loops
# For epsilon - 0.1 and Image - 148 it took 8 loops
# For epsilon - 0.1 and Image - 149 it took 33 loops
# Breaking out of loop for Image - 150 didn't fool
# For epsilon - 0.1 and Image - 151 it took 11 loops
# For epsilon - 0.1 and Image - 152 it took 17 loops
# For epsilon - 0.1 and Image - 153 it took 8 loops
# For epsilon - 0.1 and Image - 154 it took 11 loops
# For epsilon - 0.1 and Image - 155 it took 3 loops
# For epsilon - 0.1 and Image - 156 it took 4 loops
# For epsilon - 0.1 and Image - 157 it took 12 loops
# For epsilon - 0.1 and Image - 158 it took 11 loops
# For epsilon - 0.1 and Image - 159 it took 9 loops
# For epsilon - 0.1 and Image - 160 it took 4 loops
# For epsilon - 0.1 and Image - 161 it took 5 loops
# For epsilon - 0.1 and Image - 162 it took 5 loops
# For epsilon - 0.1 and Image - 163 it took 9 loops
# For epsilon - 0.1 and Image - 164 it took 3 loops
# For epsilon - 0.1 and Image - 165 it took 5 loops
# For epsilon - 0.1 and Image - 166 it took 8 loops
# For epsilon - 0.1 and Image - 167 it took 4 loops
# For epsilon - 0.1 and Image - 168 it took 3 loops
# For epsilon - 0.1 and Image - 169 it took 4 loops
# Fooled in the first iteration itself, IMAGE -  170
# Fooled in the first iteration itself, IMAGE -  171
# For epsilon - 0.1 and Image - 172 it took 2 loops
# For epsilon - 0.1 and Image - 173 it took 2 loops
# For epsilon - 0.1 and Image - 174 it took 2 loops
# For epsilon - 0.1 and Image - 175 it took 5 loops
# For epsilon - 0.1 and Image - 176 it took 12 loops
# For epsilon - 0.1 and Image - 177 it took 11 loops
# For epsilon - 0.1 and Image - 178 it took 7 loops
# For epsilon - 0.1 and Image - 179 it took 9 loops
# For epsilon - 0.1 and Image - 180 it took 8 loops
# For epsilon - 0.1 and Image - 181 it took 4 loops
# For epsilon - 0.1 and Image - 182 it took 34 loops
# For epsilon - 0.1 and Image - 183 it took 6 loops
# Breaking out of loop for Image - 184 didn't fool
# For epsilon - 0.1 and Image - 185 it took 17 loops
# For epsilon - 0.1 and Image - 186 it took 11 loops
# For epsilon - 0.1 and Image - 187 it took 3 loops
# For epsilon - 0.1 and Image - 188 it took 24 loops
# For epsilon - 0.1 and Image - 189 it took 3 loops
# For epsilon - 0.1 and Image - 190 it took 8 loops
# For epsilon - 0.1 and Image - 191 it took 4 loops
# For epsilon - 0.1 and Image - 192 it took 6 loops
# For epsilon - 0.1 and Image - 193 it took 3 loops
# For epsilon - 0.1 and Image - 194 it took 10 loops
# Fooled in the first iteration itself, IMAGE -  195
# For epsilon - 0.1 and Image - 196 it took 2 loops
# For epsilon - 0.1 and Image - 197 it took 3 loops
# For epsilon - 0.1 and Image - 198 it took 2 loops
# Fooled in the first iteration itself, IMAGE -  199
# For epsilon - 0.1 and Image - 200 it took 2 loops
# For epsilon - 0.1 and Image - 201 it took 3 loops
# For epsilon - 0.1 and Image - 202 it took 3 loops
# For epsilon - 0.1 and Image - 203 it took 3 loops
# For epsilon - 0.1 and Image - 204 it took 3 loops
# For epsilon - 0.1 and Image - 205 it took 3 loops
# For epsilon - 0.1 and Image - 206 it took 7 loops
# For epsilon - 0.1 and Image - 207 it took 8 loops
# For epsilon - 0.1 and Image - 208 it took 40 loops
# For epsilon - 0.1 and Image - 209 it took 6 loops
# For epsilon - 0.1 and Image - 210 it took 5 loops
# For epsilon - 0.1 and Image - 211 it took 5 loops
# For epsilon - 0.1 and Image - 212 it took 5 loops
# For epsilon - 0.1 and Image - 213 it took 6 loops
# For epsilon - 0.1 and Image - 214 it took 5 loops
# For epsilon - 0.1 and Image - 215 it took 9 loops
# For epsilon - 0.1 and Image - 216 it took 32 loops
# For epsilon - 0.1 and Image - 217 it took 7 loops
# For epsilon - 0.1 and Image - 218 it took 4 loops
# For epsilon - 0.1 and Image - 219 it took 9 loops
# For epsilon - 0.1 and Image - 220 it took 2 loops
# For epsilon - 0.1 and Image - 221 it took 4 loops
# For epsilon - 0.1 and Image - 222 it took 4 loops
# For epsilon - 0.1 and Image - 223 it took 3 loops
# For epsilon - 0.1 and Image - 224 it took 2 loops
# For epsilon - 0.1 and Image - 225 it took 3 loops
# For epsilon - 0.1 and Image - 226 it took 3 loops
# For epsilon - 0.1 and Image - 227 it took 3 loops
# For epsilon - 0.1 and Image - 228 it took 3 loops
# For epsilon - 0.1 and Image - 229 it took 2 loops
# For epsilon - 0.1 and Image - 230 it took 3 loops
# For epsilon - 0.1 and Image - 231 it took 26 loops
# For epsilon - 0.1 and Image - 232 it took 3 loops
# For epsilon - 0.1 and Image - 233 it took 4 loops
# For epsilon - 0.1 and Image - 234 it took 2 loops
# Breaking out of loop for Image - 235 didn't fool
# For epsilon - 0.1 and Image - 236 it took 3 loops
# For epsilon - 0.1 and Image - 237 it took 2 loops
# For epsilon - 0.1 and Image - 238 it took 2 loops
# For epsilon - 0.1 and Image - 239 it took 2 loops
# For epsilon - 0.1 and Image - 240 it took 3 loops
# For epsilon - 0.1 and Image - 241 it took 3 loops
# For epsilon - 0.1 and Image - 242 it took 2 loops
# For epsilon - 0.1 and Image - 243 it took 2 loops
# For epsilon - 0.1 and Image - 244 it took 2 loops
# For epsilon - 0.1 and Image - 245 it took 2 loops
# For epsilon - 0.1 and Image - 246 it took 2 loops
# For epsilon - 0.1 and Image - 247 it took 2 loops
# For epsilon - 0.1 and Image - 248 it took 2 loops
# For epsilon - 0.1 and Image - 249 it took 2 loops
# Epsilon: 0.1	Fool Rate = 246 / 250 = 0.984
# For epsilon - 0.2 and Image - 0 it took 94 loops
# For epsilon - 0.2 and Image - 1 it took 12 loops
# For epsilon - 0.2 and Image - 2 it took 4 loops
# For epsilon - 0.2 and Image - 3 it took 5 loops
# For epsilon - 0.2 and Image - 4 it took 17 loops
# For epsilon - 0.2 and Image - 5 it took 11 loops
# For epsilon - 0.2 and Image - 6 it took 3 loops
# Fooled in the first iteration itself, IMAGE -  7
# For epsilon - 0.2 and Image - 8 it took 3 loops
# For epsilon - 0.2 and Image - 9 it took 35 loops
# For epsilon - 0.2 and Image - 10 it took 2 loops
# For epsilon - 0.2 and Image - 11 it took 3 loops
# For epsilon - 0.2 and Image - 12 it took 2 loops
# For epsilon - 0.2 and Image - 13 it took 2 loops
# For epsilon - 0.2 and Image - 14 it took 2 loops
# For epsilon - 0.2 and Image - 15 it took 4 loops
# For epsilon - 0.2 and Image - 16 it took 5 loops
# For epsilon - 0.2 and Image - 17 it took 4 loops
# For epsilon - 0.2 and Image - 18 it took 4 loops
# For epsilon - 0.2 and Image - 19 it took 5 loops
# For epsilon - 0.2 and Image - 20 it took 4 loops
# Breaking out of loop for Image - 21 didn't fool
# For epsilon - 0.2 and Image - 22 it took 5 loops
# For epsilon - 0.2 and Image - 23 it took 5 loops
# For epsilon - 0.2 and Image - 24 it took 6 loops
# For epsilon - 0.2 and Image - 25 it took 5 loops
# For epsilon - 0.2 and Image - 26 it took 7 loops
# For epsilon - 0.2 and Image - 27 it took 3 loops
# For epsilon - 0.2 and Image - 28 it took 4 loops
# For epsilon - 0.2 and Image - 29 it took 3 loops
# For epsilon - 0.2 and Image - 30 it took 2 loops
# Fooled in the first iteration itself, IMAGE -  31
# For epsilon - 0.2 and Image - 32 it took 2 loops
# For epsilon - 0.2 and Image - 33 it took 2 loops
# For epsilon - 0.2 and Image - 34 it took 2 loops
# For epsilon - 0.2 and Image - 35 it took 2 loops
# For epsilon - 0.2 and Image - 36 it took 2 loops
# For epsilon - 0.2 and Image - 37 it took 2 loops
# For epsilon - 0.2 and Image - 38 it took 2 loops
# For epsilon - 0.2 and Image - 39 it took 3 loops
# For epsilon - 0.2 and Image - 40 it took 5 loops
# For epsilon - 0.2 and Image - 41 it took 3 loops
# For epsilon - 0.2 and Image - 42 it took 3 loops
# For epsilon - 0.2 and Image - 43 it took 3 loops
# For epsilon - 0.2 and Image - 44 it took 4 loops
# Breaking out of loop for Image - 45 didn't fool
# For epsilon - 0.2 and Image - 46 it took 4 loops
# Breaking out of loop for Image - 47 didn't fool
# For epsilon - 0.2 and Image - 48 it took 6 loops
# For epsilon - 0.2 and Image - 49 it took 5 loops
# For epsilon - 0.2 and Image - 50 it took 6 loops
# Breaking out of loop for Image - 51 didn't fool
# For epsilon - 0.2 and Image - 52 it took 8 loops
# For epsilon - 0.2 and Image - 53 it took 11 loops
# For epsilon - 0.2 and Image - 54 it took 5 loops
# For epsilon - 0.2 and Image - 55 it took 9 loops
# Breaking out of loop for Image - 56 didn't fool
# For epsilon - 0.2 and Image - 57 it took 10 loops
# For epsilon - 0.2 and Image - 58 it took 13 loops
# For epsilon - 0.2 and Image - 59 it took 15 loops
# For epsilon - 0.2 and Image - 60 it took 2 loops
# For epsilon - 0.2 and Image - 61 it took 2 loops
# For epsilon - 0.2 and Image - 62 it took 3 loops
# For epsilon - 0.2 and Image - 63 it took 4 loops
# For epsilon - 0.2 and Image - 64 it took 3 loops
# Breaking out of loop for Image - 65 didn't fool
# For epsilon - 0.2 and Image - 66 it took 17 loops
# For epsilon - 0.2 and Image - 67 it took 5 loops
# For epsilon - 0.2 and Image - 68 it took 4 loops
# For epsilon - 0.2 and Image - 69 it took 5 loops
# For epsilon - 0.2 and Image - 70 it took 4 loops
# For epsilon - 0.2 and Image - 71 it took 2 loops
# For epsilon - 0.2 and Image - 72 it took 6 loops
# For epsilon - 0.2 and Image - 73 it took 5 loops
# For epsilon - 0.2 and Image - 74 it took 4 loops
# For epsilon - 0.2 and Image - 75 it took 5 loops
# For epsilon - 0.2 and Image - 76 it took 4 loops
# For epsilon - 0.2 and Image - 77 it took 7 loops
# For epsilon - 0.2 and Image - 78 it took 10 loops
# For epsilon - 0.2 and Image - 79 it took 12 loops
# For epsilon - 0.2 and Image - 80 it took 3 loops
# For epsilon - 0.2 and Image - 81 it took 2 loops
# For epsilon - 0.2 and Image - 82 it took 2 loops
# For epsilon - 0.2 and Image - 83 it took 17 loops
# For epsilon - 0.2 and Image - 84 it took 35 loops
# For epsilon - 0.2 and Image - 85 it took 3 loops
# For epsilon - 0.2 and Image - 86 it took 2 loops
# For epsilon - 0.2 and Image - 87 it took 2 loops
# For epsilon - 0.2 and Image - 88 it took 2 loops
# Fooled in the first iteration itself, IMAGE -  89
# Breaking out of loop for Image - 90 didn't fool
# For epsilon - 0.2 and Image - 91 it took 21 loops
# For epsilon - 0.2 and Image - 92 it took 4 loops
# For epsilon - 0.2 and Image - 93 it took 26 loops
# Breaking out of loop for Image - 94 didn't fool
# For epsilon - 0.2 and Image - 95 it took 37 loops
# For epsilon - 0.2 and Image - 96 it took 5 loops
# For epsilon - 0.2 and Image - 97 it took 6 loops
# For epsilon - 0.2 and Image - 98 it took 66 loops
# For epsilon - 0.2 and Image - 99 it took 4 loops
# For epsilon - 0.2 and Image - 100 it took 7 loops
# For epsilon - 0.2 and Image - 101 it took 4 loops
# For epsilon - 0.2 and Image - 102 it took 6 loops
# For epsilon - 0.2 and Image - 103 it took 7 loops
# For epsilon - 0.2 and Image - 104 it took 6 loops
# For epsilon - 0.2 and Image - 105 it took 9 loops
# For epsilon - 0.2 and Image - 106 it took 26 loops
# For epsilon - 0.2 and Image - 107 it took 4 loops
# For epsilon - 0.2 and Image - 108 it took 5 loops
# For epsilon - 0.2 and Image - 109 it took 6 loops
# For epsilon - 0.2 and Image - 110 it took 5 loops
# For epsilon - 0.2 and Image - 111 it took 10 loops
# For epsilon - 0.2 and Image - 112 it took 3 loops
# For epsilon - 0.2 and Image - 113 it took 3 loops
# For epsilon - 0.2 and Image - 114 it took 3 loops
# For epsilon - 0.2 and Image - 115 it took 8 loops
# For epsilon - 0.2 and Image - 116 it took 6 loops
# For epsilon - 0.2 and Image - 117 it took 4 loops
# For epsilon - 0.2 and Image - 118 it took 8 loops
# For epsilon - 0.2 and Image - 119 it took 8 loops
# For epsilon - 0.2 and Image - 120 it took 3 loops
# For epsilon - 0.2 and Image - 121 it took 11 loops
# For epsilon - 0.2 and Image - 122 it took 5 loops
# For epsilon - 0.2 and Image - 123 it took 7 loops
# For epsilon - 0.2 and Image - 124 it took 6 loops
# For epsilon - 0.2 and Image - 125 it took 4 loops
# For epsilon - 0.2 and Image - 126 it took 2 loops
# For epsilon - 0.2 and Image - 127 it took 2 loops
# For epsilon - 0.2 and Image - 128 it took 2 loops
# For epsilon - 0.2 and Image - 129 it took 2 loops
# Fooled in the first iteration itself, IMAGE -  130
# Fooled in the first iteration itself, IMAGE -  131
# For epsilon - 0.2 and Image - 132 it took 2 loops
# Fooled in the first iteration itself, IMAGE -  133
# Fooled in the first iteration itself, IMAGE -  134
# For epsilon - 0.2 and Image - 135 it took 3 loops
# For epsilon - 0.2 and Image - 136 it took 4 loops
# For epsilon - 0.2 and Image - 137 it took 4 loops
# For epsilon - 0.2 and Image - 138 it took 2 loops
# For epsilon - 0.2 and Image - 139 it took 5 loops
# For epsilon - 0.2 and Image - 140 it took 2 loops
# Fooled in the first iteration itself, IMAGE -  141
# For epsilon - 0.2 and Image - 142 it took 3 loops
# Fooled in the first iteration itself, IMAGE -  143
# For epsilon - 0.2 and Image - 144 it took 2 loops
# For epsilon - 0.2 and Image - 145 it took 3 loops
# For epsilon - 0.2 and Image - 146 it took 4 loops
# For epsilon - 0.2 and Image - 147 it took 5 loops
# For epsilon - 0.2 and Image - 148 it took 4 loops
# For epsilon - 0.2 and Image - 149 it took 19 loops
# Breaking out of loop for Image - 150 didn't fool
# For epsilon - 0.2 and Image - 151 it took 12 loops
# For epsilon - 0.2 and Image - 152 it took 45 loops
# For epsilon - 0.2 and Image - 153 it took 6 loops
# For epsilon - 0.2 and Image - 154 it took 18 loops
# For epsilon - 0.2 and Image - 155 it took 3 loops
# For epsilon - 0.2 and Image - 156 it took 7 loops
# For epsilon - 0.2 and Image - 157 it took 13 loops
# For epsilon - 0.2 and Image - 158 it took 6 loops
# For epsilon - 0.2 and Image - 159 it took 78 loops
# For epsilon - 0.2 and Image - 160 it took 4 loops
# For epsilon - 0.2 and Image - 161 it took 4 loops
# For epsilon - 0.2 and Image - 162 it took 4 loops
# For epsilon - 0.2 and Image - 163 it took 5 loops
# For epsilon - 0.2 and Image - 164 it took 4 loops
# For epsilon - 0.2 and Image - 165 it took 5 loops
# For epsilon - 0.2 and Image - 166 it took 8 loops
# For epsilon - 0.2 and Image - 167 it took 12 loops
# For epsilon - 0.2 and Image - 168 it took 3 loops
# For epsilon - 0.2 and Image - 169 it took 5 loops
# Fooled in the first iteration itself, IMAGE -  170
# Fooled in the first iteration itself, IMAGE -  171
# For epsilon - 0.2 and Image - 172 it took 4 loops
# Fooled in the first iteration itself, IMAGE -  173
# Fooled in the first iteration itself, IMAGE -  174
# For epsilon - 0.2 and Image - 175 it took 4 loops
# For epsilon - 0.2 and Image - 176 it took 16 loops
# For epsilon - 0.2 and Image - 177 it took 22 loops
# For epsilon - 0.2 and Image - 178 it took 7 loops
# For epsilon - 0.2 and Image - 179 it took 19 loops
# For epsilon - 0.2 and Image - 180 it took 31 loops
# For epsilon - 0.2 and Image - 181 it took 5 loops
# For epsilon - 0.2 and Image - 182 it took 12 loops
# For epsilon - 0.2 and Image - 183 it took 4 loops
# Breaking out of loop for Image - 184 didn't fool
# For epsilon - 0.2 and Image - 185 it took 66 loops
# Breaking out of loop for Image - 186 didn't fool
# For epsilon - 0.2 and Image - 187 it took 3 loops
# Breaking out of loop for Image - 188 didn't fool
# For epsilon - 0.2 and Image - 189 it took 3 loops
# For epsilon - 0.2 and Image - 190 it took 3 loops
# For epsilon - 0.2 and Image - 191 it took 5 loops
# For epsilon - 0.2 and Image - 192 it took 3 loops
# For epsilon - 0.2 and Image - 193 it took 6 loops
# For epsilon - 0.2 and Image - 194 it took 12 loops
# Fooled in the first iteration itself, IMAGE -  195
# For epsilon - 0.2 and Image - 196 it took 2 loops
# For epsilon - 0.2 and Image - 197 it took 2 loops
# For epsilon - 0.2 and Image - 198 it took 2 loops
# Fooled in the first iteration itself, IMAGE -  199
# For epsilon - 0.2 and Image - 200 it took 2 loops
# For epsilon - 0.2 and Image - 201 it took 3 loops
# For epsilon - 0.2 and Image - 202 it took 3 loops
# For epsilon - 0.2 and Image - 203 it took 3 loops
# For epsilon - 0.2 and Image - 204 it took 3 loops
# For epsilon - 0.2 and Image - 205 it took 2 loops
# For epsilon - 0.2 and Image - 206 it took 7 loops
# For epsilon - 0.2 and Image - 207 it took 34 loops
# For epsilon - 0.2 and Image - 208 it took 40 loops
# For epsilon - 0.2 and Image - 209 it took 4 loops
# For epsilon - 0.2 and Image - 210 it took 5 loops
# For epsilon - 0.2 and Image - 211 it took 4 loops
# For epsilon - 0.2 and Image - 212 it took 5 loops
# For epsilon - 0.2 and Image - 213 it took 5 loops
# For epsilon - 0.2 and Image - 214 it took 6 loops
# For epsilon - 0.2 and Image - 215 it took 95 loops
# For epsilon - 0.2 and Image - 216 it took 7 loops
# For epsilon - 0.2 and Image - 217 it took 5 loops
# For epsilon - 0.2 and Image - 218 it took 3 loops
# For epsilon - 0.2 and Image - 219 it took 7 loops
# For epsilon - 0.2 and Image - 220 it took 2 loops
# For epsilon - 0.2 and Image - 221 it took 4 loops
# For epsilon - 0.2 and Image - 222 it took 4 loops
# For epsilon - 0.2 and Image - 223 it took 3 loops
# For epsilon - 0.2 and Image - 224 it took 3 loops
# For epsilon - 0.2 and Image - 225 it took 3 loops
# For epsilon - 0.2 and Image - 226 it took 4 loops
# For epsilon - 0.2 and Image - 227 it took 4 loops
# For epsilon - 0.2 and Image - 228 it took 5 loops
# For epsilon - 0.2 and Image - 229 it took 3 loops
# For epsilon - 0.2 and Image - 230 it took 3 loops
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Breaking out of loop for Image - 231 didn't fool
# For epsilon - 0.2 and Image - 232 it took 3 loops
# For epsilon - 0.2 and Image - 233 it took 4 loops
# For epsilon - 0.2 and Image - 234 it took 2 loops
# Breaking out of loop for Image - 235 didn't fool
# For epsilon - 0.2 and Image - 236 it took 3 loops
# For epsilon - 0.2 and Image - 237 it took 2 loops
# For epsilon - 0.2 and Image - 238 it took 2 loops
# For epsilon - 0.2 and Image - 239 it took 2 loops
# For epsilon - 0.2 and Image - 240 it took 2 loops
# For epsilon - 0.2 and Image - 241 it took 4 loops
# For epsilon - 0.2 and Image - 242 it took 2 loops
# For epsilon - 0.2 and Image - 243 it took 2 loops
# For epsilon - 0.2 and Image - 244 it took 2 loops
# For epsilon - 0.2 and Image - 245 it took 2 loops
# For epsilon - 0.2 and Image - 246 it took 2 loops
# Fooled in the first iteration itself, IMAGE -  247
# For epsilon - 0.2 and Image - 248 it took 2 loops
# For epsilon - 0.2 and Image - 249 it took 3 loops
# Epsilon: 0.2	Fool Rate = 236 / 250 = 0.944
# For epsilon - 0.4 and Image - 0 it took 12 loops
# Breaking out of loop for Image - 1 didn't fool
# For epsilon - 0.4 and Image - 2 it took 9 loops
# For epsilon - 0.4 and Image - 3 it took 18 loops
# For epsilon - 0.4 and Image - 4 it took 5 loops
# For epsilon - 0.4 and Image - 5 it took 3 loops
# For epsilon - 0.4 and Image - 6 it took 2 loops
# Fooled in the first iteration itself, IMAGE -  7
# For epsilon - 0.4 and Image - 8 it took 2 loops
# For epsilon - 0.4 and Image - 9 it took 17 loops
# For epsilon - 0.4 and Image - 10 it took 5 loops
# For epsilon - 0.4 and Image - 11 it took 2 loops
# For epsilon - 0.4 and Image - 12 it took 13 loops
# For epsilon - 0.4 and Image - 13 it took 5 loops
# For epsilon - 0.4 and Image - 14 it took 3 loops
# For epsilon - 0.4 and Image - 15 it took 34 loops
# For epsilon - 0.4 and Image - 16 it took 25 loops
# For epsilon - 0.4 and Image - 17 it took 89 loops
# For epsilon - 0.4 and Image - 18 it took 9 loops
# For epsilon - 0.4 and Image - 19 it took 6 loops
# For epsilon - 0.4 and Image - 20 it took 3 loops
# Breaking out of loop for Image - 21 didn't fool
# For epsilon - 0.4 and Image - 22 it took 4 loops
# Breaking out of loop for Image - 23 didn't fool
# For epsilon - 0.4 and Image - 24 it took 3 loops
# For epsilon - 0.4 and Image - 25 it took 3 loops
# For epsilon - 0.4 and Image - 26 it took 2 loops
# For epsilon - 0.4 and Image - 27 it took 2 loops
# For epsilon - 0.4 and Image - 28 it took 7 loops
# For epsilon - 0.4 and Image - 29 it took 3 loops
# Fooled in the first iteration itself, IMAGE -  30
# For epsilon - 0.4 and Image - 31 it took 2 loops
# For epsilon - 0.4 and Image - 32 it took 2 loops
# For epsilon - 0.4 and Image - 33 it took 2 loops
# For epsilon - 0.4 and Image - 34 it took 9 loops
# For epsilon - 0.4 and Image - 35 it took 10 loops
# For epsilon - 0.4 and Image - 36 it took 4 loops
# Breaking out of loop for Image - 37 didn't fool
# For epsilon - 0.4 and Image - 38 it took 3 loops
# For epsilon - 0.4 and Image - 39 it took 5 loops
# For epsilon - 0.4 and Image - 40 it took 4 loops
# For epsilon - 0.4 and Image - 41 it took 2 loops
# For epsilon - 0.4 and Image - 42 it took 4 loops
# For epsilon - 0.4 and Image - 43 it took 3 loops
# For epsilon - 0.4 and Image - 44 it took 4 loops
# Breaking out of loop for Image - 45 didn't fool
# For epsilon - 0.4 and Image - 46 it took 3 loops
# Breaking out of loop for Image - 47 didn't fool
# For epsilon - 0.4 and Image - 48 it took 33 loops
# For epsilon - 0.4 and Image - 49 it took 3 loops
# For epsilon - 0.4 and Image - 50 it took 3 loops
# Breaking out of loop for Image - 51 didn't fool
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Breaking out of loop for Image - 52 didn't fool
# For epsilon - 0.4 and Image - 53 it took 5 loops
# For epsilon - 0.4 and Image - 54 it took 3 loops
# For epsilon - 0.4 and Image - 55 it took 10 loops
# For epsilon - 0.4 and Image - 56 it took 87 loops
# Breaking out of loop for Image - 57 didn't fool
# Breaking out of loop for Image - 58 didn't fool
# For epsilon - 0.4 and Image - 59 it took 166 loops
# Breaking out of loop for Image - 60 didn't fool
# For epsilon - 0.4 and Image - 61 it took 2 loops
# For epsilon - 0.4 and Image - 62 it took 3 loops
# For epsilon - 0.4 and Image - 63 it took 3 loops
# For epsilon - 0.4 and Image - 64 it took 3 loops
# Breaking out of loop for Image - 65 didn't fool
# For epsilon - 0.4 and Image - 66 it took 13 loops
# Breaking out of loop for Image - 67 didn't fool
# For epsilon - 0.4 and Image - 68 it took 6 loops
# For epsilon - 0.4 and Image - 69 it took 9 loops
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# ...
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Breaking out of loop for Image - 219 didn't fool
# For epsilon - 1 and Image - 220 it took 18 loops
# For epsilon - 1 and Image - 221 it took 2 loops
# For epsilon - 1 and Image - 222 it took 9 loops
# For epsilon - 1 and Image - 223 it took 5 loops
# For epsilon - 1 and Image - 224 it took 4 loops
# For epsilon - 1 and Image - 225 it took 2 loops
# For epsilon - 1 and Image - 226 it took 4 loops
# For epsilon - 1 and Image - 227 it took 3 loops
# For epsilon - 1 and Image - 228 it took 8 loops
# For epsilon - 1 and Image - 229 it took 3 loops
# Fooled in the first iteration itself, IMAGE -  230
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Fooled in the first iteration itself, IMAGE -  231
# For epsilon - 1 and Image - 232 it took 2 loops
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Issue in tensor -  torch.Size([1, 3, 160, 160])
# Breaking out of loop for Image - 233 didn't fool
# Fooled in the first iteration itself, IMAGE -  234
# Breaking out of loop for Image - 235 didn't fool
# For epsilon - 1 and Image - 236 it took 2 loops
# For epsilon - 1 and Image - 237 it took 9 loops
# Fooled in the first iteration itself, IMAGE -  238
# Fooled in the first iteration itself, IMAGE -  239
# For epsilon - 1 and Image - 240 it took 65 loops
# For epsilon - 1 and Image - 241 it took 19 loops
# For epsilon - 1 and Image - 242 it took 3 loops
# For epsilon - 1 and Image - 243 it took 47 loops
# For epsilon - 1 and Image - 244 it took 3 loops
# Fooled in the first iteration itself, IMAGE -  245
# For epsilon - 1 and Image - 246 it took 3 loops
# Breaking out of loop for Image - 247 didn't fool
# Fooled in the first iteration itself, IMAGE -  248
# For epsilon - 1 and Image - 249 it took 2 loops
# Epsilon: 1	Fool Rate = 196 / 250 = 0.784
# Time taken for this run -  6485.695670843124
# 0
# 246
# 236
# 220
# 193
# 196

# %%
frame = faces[0].detach().cpu().numpy()
frame = np.transpose(frame, (1,2,0))
frame = (frame*128)+127.5
frame = frame.astype(np.uint8)
    
print(faces.shape)
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

cv2.imwrite("Multiple-N-F-C.png", frame)
# Out:
# torch.Size([1, 3, 160, 160])
# True
